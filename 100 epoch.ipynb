# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore")
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, Dropout, MaxPool1D, Flatten
from sklearn.model_selection import train_test_split

# %%
# Setting the parameter to plot at 30x15 size
plt.rcParams['figure.figsize'] = 30, 15

# %%
root_folder_train = r'C:\Users\acer\Desktop\xxx\train'
root_folder_test = r'C:\Users\acer\Desktop\xxx\test'
category = ['Normal', 'Abnormal']
destination = r'C:\Users\acer\Desktop\New folder'

# %%
# Function to load the dataset and do the required formatting to be able to feed the data into the Keras Model
def load_data(root_folder):
    # These are delcarations of variables that have been used inside the for loop
    final_list = list()
    labels = list()
    # It is iterating through both the categories Normal and Abnormal
    for cat in category:
        # It is taking and processing each file in the folder
        #for filename in os.listdir(root_folder+cat):
        for filename in os.listdir(os.path.join(root_folder, cat)):
            
            # Read each file for each category and drop the unnecessary columns
            path = os.path.join(root_folder, cat, filename)
            #path = root_folder + cat + '\\' + filename
            df = pd.read_csv(path) # Read the CSV using inbuilt Pandas Function
            df.drop(index=0, axis=0, inplace=True) # Drop the first row, which contains the units of measurement (useless for our use case)
            df=df.iloc[:7680]
            df.columns = ["time", "ECG0", "ECG1"] # Rename the columns for convinience and easy access of the columns
            df.drop(['time'], axis=1, inplace=True) # Drop the time column, as we are not using it as a time series. We are using the indexes instead
            df.ECG0 = pd.to_numeric(df.ECG0) # The data by default is in the form of an object, Convert each row into numeric or floating point
            df.ECG1 = pd.to_numeric(df.ECG1)
            
            print(filename, len(df))
            
            # Split each file into 6 parts and then make each of them a new row by transposing
            df_split = np.array_split(df, 30) # Split the dataset into 30 different sets. This is not mandatory, but is suggested since the dataset size is less
            for splitted_array in df_split:
                final_list.append(np.array(splitted_array)) # After splitting, we are appending all the splitted arrays into 1 single large array of 3 dimentions
                # The following if-else block is used to create labels. We have taken '1' for AF ECG and '0' for Normal ECG
                # This is not the ideal way to create labels, but this is the most simplest way for this situation
                if cat == 'Normal':
                    labels.append(0)
                if cat == 'Abnormal':
                    labels.append(1)

    # Before returning, convert the lists to arrays and increase the dmentions for being able to feed into the Neural Network
    return np.array(final_list), np.expand_dims(np.array(labels), axis=1)

# %%
# Load the training and testing dataset separately by calling the function for each of their root folder locations
X_train, y_train = load_data(root_folder_train)
X_test, y_test = load_data(root_folder_test)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (15).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (3).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples (3).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples.csv 7680
# (720, 256, 2) (720, 1)
# (180, 256, 2) (180, 1)

# %%
# Build the model

# The model architecture type is sequential hence that is used
model = Sequential()

# We are using 4 convolution layers for feature extraction
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu', input_shape=(256, 2)))
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2)) # This is the dropout layer. It's main function is to inactivate 20% of neurons in order to prevent overfitting
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(MaxPool1D(pool_size=128)) # We use MaxPooling with a filter size of 128. This also contributes to generalization
model.add(Dropout(0.2))

# The prevous step gices an output of multi dimentional data, which cannot be fead directly into the feed forward neural network. Hence, the model is flattened
model.add(Flatten())
# One hidden layer of 128 neurons have been used in order to have better classification results
model.add(Dense(units=128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.5))
# The final neuron HAS to be 1 in number and cannot be more than that. This is because this is a binary classification problem and only 1 neuron is enough to denote the class '1' or '0'
model.add(Dense(units=1, activation='sigmoid'))

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 256, 512)          33280
#
#  conv1d_5 (Conv1D)           (None, 256, 512)          8389120
#
#  dropout_4 (Dropout)         (None, 256, 512)          0
#
#  conv1d_6 (Conv1D)           (None, 256, 256)          4194560
#
#  dropout_5 (Dropout)         (None, 256, 256)          0
#
#  conv1d_7 (Conv1D)           (None, 256, 256)          2097408
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 256)            0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 2, 256)            0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14780161 (56.38 MB)
# Trainable params: 14780161 (56.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the mode
# To my experience, the Stocastic Gradient Descent Optimizer works the best. Adam optimizer also works but not as good as SGD
optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(X_train, y_train,  batch_size=80, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 137s 15s/step - loss: 13.4406 - accuracy: 0.5931 - val_loss: 0.2343 - val_accuracy: 0.9667
# Epoch 2/100
# 9/9 [==============================] - 136s 15s/step - loss: 1.5122 - accuracy: 0.7458 - val_loss: 0.1717 - val_accuracy: 0.9667
# Epoch 3/100
# 9/9 [==============================] - 140s 16s/step - loss: 1.1619 - accuracy: 0.7583 - val_loss: 0.2055 - val_accuracy: 0.9667
# Epoch 4/100
# 9/9 [==============================] - 137s 15s/step - loss: 0.7378 - accuracy: 0.8208 - val_loss: 0.1993 - val_accuracy: 0.9500
# Epoch 5/100
# 9/9 [==============================] - 135s 15s/step - loss: 0.5443 - accuracy: 0.8625 - val_loss: 0.1871 - val_accuracy: 0.9556
# Epoch 6/100
# 9/9 [==============================] - 138s 16s/step - loss: 0.5895 - accuracy: 0.8292 - val_loss: 0.1874 - val_accuracy: 0.9611
# Epoch 7/100
# 9/9 [==============================] - 139s 16s/step - loss: 0.6452 - accuracy: 0.8347 - val_loss: 0.1582 - val_accuracy: 0.9778
# Epoch 8/100
# 9/9 [==============================] - 139s 15s/step - loss: 0.4512 - accuracy: 0.8569 - val_loss: 0.1571 - val_accuracy: 0.9833
# Epoch 9/100
# 9/9 [==============================] - 142s 16s/step - loss: 0.4232 - accuracy: 0.8597 - val_loss: 0.1642 - val_accuracy: 0.9778
# Epoch 10/100
# 9/9 [==============================] - 139s 16s/step - loss: 0.4525 - accuracy: 0.8847 - val_loss: 0.1823 - val_accuracy: 0.9667
# Epoch 11/100
# 9/9 [==============================] - 139s 16s/step - loss: 0.4977 - accuracy: 0.8514 - val_loss: 0.1827 - val_accuracy: 0.9778
# Epoch 12/100
# 9/9 [==============================] - 139s 16s/step - loss: 0.3451 - accuracy: 0.8819 - val_loss: 0.1908 - val_accuracy: 0.9722
# Epoch 13/100
# 9/9 [==============================] - 140s 16s/step - loss: 0.4253 - accuracy: 0.8875 - val_loss: 0.1782 - val_accuracy: 0.9833
# Epoch 14/100
# 9/9 [==============================] - 140s 16s/step - loss: 0.2630 - accuracy: 0.9097 - val_loss: 0
100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0742 - accuracy: 0.9764 - val_loss: 0.0249 - val_accuracy: 0.9944
# Epoch 73/100
# 9/9 [==============================] - 76s 9s/step - loss: 0.0611 - accuracy: 0.9847 - val_loss: 0.0300 - val_accuracy: 0.9944
# Epoch 74/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0763 - accuracy: 0.9764 - val_loss: 0.0209 - val_accuracy: 0.9944
# Epoch 75/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0574 - accuracy: 0.9861 - val_loss: 0.0241 - val_accuracy: 0.9944
# Epoch 76/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0708 - accuracy: 0.9722 - val_loss: 0.0170 - val_accuracy: 0.9944
# Epoch 77/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.0179 - val_accuracy: 0.9944
# Epoch 78/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0616 - accuracy: 0.9764 - val_loss: 0.0143 - val_accuracy: 0.9944
# Epoch 79/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 0.0176 - val_accuracy: 0.9944
# Epoch 80/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0444 - accuracy: 0.9875 - val_loss: 0.0186 - val_accuracy: 0.9944
# Epoch 81/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0658 - accuracy: 0.9847 - val_loss: 0.0190 - val_accuracy: 0.9944
# Epoch 82/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0389 - accuracy: 0.9847 - val_loss: 0.0197 - val_accuracy: 0.9944
# Epoch 83/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0562 - accuracy: 0.9833 - val_loss: 0.0222 - val_accuracy: 0.9944
# Epoch 84/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0342 - accuracy: 0.9903 - val_loss: 0.0165 - val_accuracy: 0.9944
# Epoch 85/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.0159 - val_accuracy: 0.9944
# Epoch 86/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0409 - accuracy: 0.9875 - val_loss: 0.0182 - val_accuracy: 0.9944
# Epoch 87/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0614 - accuracy: 0.9847 - val_loss: 0.0206 - val_accuracy: 0.9944
# Epoch 88/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0439 - accuracy: 0.9875 - val_loss: 0.0171 - val_accuracy: 0.9944
# Epoch 89/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0352 - accuracy: 0.9903 - val_loss: 0.0101 - val_accuracy: 0.9944
# Epoch 90/100
# 9/9 [==============================] - 76s 9s/step - loss: 0.0551 - accuracy: 0.9833 - val_loss: 0.0183 - val_accuracy: 0.9944
# Epoch 91/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0467 - accuracy: 0.9861 - val_loss: 0.0106 - val_accuracy: 0.9944
# Epoch 92/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0515 - accuracy: 0.9875 - val_loss: 0.0126 - val_accuracy: 0.9944
# Epoch 93/100
# 9/9 [==============================] - 76s 9s/step - loss: 0.0273 - accuracy: 0.9889 - val_loss: 0.0226 - val_accuracy: 0.9944
# Epoch 94/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0690 - accuracy: 0.9764 - val_loss: 0.0184 - val_accuracy: 0.9944
# Epoch 95/100
# 9/9 [==============================] - 75s 8s/step - loss: 0.0276 - accuracy: 0.9917 - val_loss: 0.0152 - val_accuracy: 0.9944
# Epoch 96/100
# 9/9 [==============================] - 76s 9s/step - loss: 0.0625 - accuracy: 0.9847 - val_loss: 0.0153 - val_accuracy: 0.9944
# Epoch 97/100
# 9/9 [==============================] - 77s 9s/step - loss: 0.0642 - accuracy: 0.9889 - val_loss: 0.0161 - val_accuracy: 0.9944
# Epoch 98/100
# 9/9 [==============================] - 76s 9s/step - loss: 0.0403 - accuracy: 0.9861 - val_loss: 0.0227 - val_accuracy: 0.9944
# Epoch 99/100
# 9/9 [==============================] - 76s 8s/step - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.0200 - val_accuracy: 0.9944
# Epoch 100/100
# 9/9 [==============================] - 77s 9s/step - loss: 0.0560 - accuracy: 0.9847 - val_loss: 0.0127 - val_accuracy: 0.9944

# %%
# Plot the model Accuracy graph (Ideally, it should be Logarithmic shape)
plt.plot(history.history['accuracy'],'r',linewidth=3.0, label='Training Accuracy')
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0, label='Testing Accuracy')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# Plot the model Loss graph (Ideally it should be Exponentially decreasing shape)
plt.plot(history.history['loss'], 'g', linewidth=3.0, label='Training Loss')
plt.plot(history.history['val_loss'], 'y', linewidth=3.0, label='Testing Loss')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')
