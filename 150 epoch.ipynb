# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore")
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, Dropout, MaxPool1D, Flatten
from sklearn.model_selection import train_test_split

# %%
# Setting the parameter to plot at 30x15 size
plt.rcParams['figure.figsize'] = 30, 15

# %%
root_folder_train = r'C:\Users\acer\Desktop\xxx\train'
root_folder_test = r'C:\Users\acer\Desktop\xxx\test'
category = ['Normal', 'Abnormal']
destination = r'C:\Users\acer\Desktop\New folder'

# %%
# Function to load the dataset and do the required formatting to be able to feed the data into the Keras Model
def load_data(root_folder):
    # These are delcarations of variables that have been used inside the for loop
    final_list = list()
    labels = list()
    # It is iterating through both the categories Normal and Abnormal
    for cat in category:
        # It is taking and processing each file in the folder
        #for filename in os.listdir(root_folder+cat):
        for filename in os.listdir(os.path.join(root_folder, cat)):
            
            # Read each file for each category and drop the unnecessary columns
            path = os.path.join(root_folder, cat, filename)
            #path = root_folder + cat + '\\' + filename
            df = pd.read_csv(path) # Read the CSV using inbuilt Pandas Function
            df.drop(index=0, axis=0, inplace=True) # Drop the first row, which contains the units of measurement (useless for our use case)
            df=df.iloc[:7680]
            df.columns = ["time", "ECG0", "ECG1"] # Rename the columns for convinience and easy access of the columns
            df.drop(['time'], axis=1, inplace=True) # Drop the time column, as we are not using it as a time series. We are using the indexes instead
            df.ECG0 = pd.to_numeric(df.ECG0) # The data by default is in the form of an object, Convert each row into numeric or floating point
            df.ECG1 = pd.to_numeric(df.ECG1)
            
            print(filename, len(df))
            
            # Split each file into 6 parts and then make each of them a new row by transposing
            df_split = np.array_split(df, 30) # Split the dataset into 30 different sets. This is not mandatory, but is suggested since the dataset size is less
            for splitted_array in df_split:
                final_list.append(np.array(splitted_array)) # After splitting, we are appending all the splitted arrays into 1 single large array of 3 dimentions
                # The following if-else block is used to create labels. We have taken '1' for AF ECG and '0' for Normal ECG
                # This is not the ideal way to create labels, but this is the most simplest way for this situation
                if cat == 'Normal':
                    labels.append(0)
                if cat == 'Abnormal':
                    labels.append(1)

    # Before returning, convert the lists to arrays and increase the dmentions for being able to feed into the Neural Network
    return np.array(final_list), np.expand_dims(np.array(labels), axis=1)

# %%
# Load the training and testing dataset separately by calling the function for each of their root folder locations
X_train, y_train = load_data(root_folder_train)
X_test, y_test = load_data(root_folder_test)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (15).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (3).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples (3).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples.csv 7680
# (720, 256, 2) (720, 1)
# (180, 256, 2) (180, 1)

# %%
# Build the model

# The model architecture type is sequential hence that is used
model = Sequential()

# We are using 4 convolution layers for feature extraction
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu', input_shape=(256, 2)))
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2)) # This is the dropout layer. It's main function is to inactivate 20% of neurons in order to prevent overfitting
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(MaxPool1D(pool_size=128)) # We use MaxPooling with a filter size of 128. This also contributes to generalization
model.add(Dropout(0.2))

# The prevous step gices an output of multi dimentional data, which cannot be fead directly into the feed forward neural network. Hence, the model is flattened
model.add(Flatten())
# One hidden layer of 128 neurons have been used in order to have better classification results
model.add(Dense(units=128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.5))
# The final neuron HAS to be 1 in number and cannot be more than that. This is because this is a binary classification problem and only 1 neuron is enough to denote the class '1' or '0'
model.add(Dense(units=1, activation='sigmoid'))

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 256, 512)          33280
#
#  conv1d_9 (Conv1D)           (None, 256, 512)          8389120
#
#  dropout_8 (Dropout)         (None, 256, 512)          0
#
#  conv1d_10 (Conv1D)          (None, 256, 256)          4194560
#
#  dropout_9 (Dropout)         (None, 256, 256)          0
#
#  conv1d_11 (Conv1D)          (None, 256, 256)          2097408
#
#  max_pooling1d_2 (MaxPoolin  (None, 2, 256)            0
#  g1D)
#
#  dropout_10 (Dropout)        (None, 2, 256)            0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14780161 (56.38 MB)
# Trainable params: 14780161 (56.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the mode
# To my experience, the Stocastic Gradient Descent Optimizer works the best. Adam optimizer also works but not as good as SGD
optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(X_train, y_train,  batch_size=80, epochs=150, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 9/9 [==============================] - 74s 8s/step - loss: 11.2207 - accuracy: 0.5569 - val_loss: 0.6313 - val_accuracy: 0.7611
# Epoch 2/150
# 9/9 [==============================] - 76s 8s/step - loss: 1.7255 - accuracy: 0.6708 - val_loss: 0.3876 - val_accuracy: 0.8333
# Epoch 3/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.9764 - accuracy: 0.7292 - val_loss: 0.4330 - val_accuracy: 0.7889
# Epoch 4/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.8077 - accuracy: 0.7431 - val_loss: 0.2397 - val_accuracy: 0.9444
# Epoch 5/150
# 9/9 [==============================] - 76s 9s/step - loss: 0.6693 - accuracy: 0.7625 - val_loss: 0.2854 - val_accuracy: 0.9333
# Epoch 6/150
# 9/9 [==============================] - 74s 8s/step - loss: 0.5874 - accuracy: 0.7986 - val_loss: 0.3013 - val_accuracy: 0.9056
# Epoch 7/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.5444 - accuracy: 0.8000 - val_loss: 0.2793 - val_accuracy: 0.9222
# Epoch 8/150
# 9/9 [==============================] - 74s 8s/step - loss: 0.5294 - accuracy: 0.8042 - val_loss: 0.2944 - val_accuracy: 0.9111
# Epoch 9/150
# 9/9 [==============================] - 75s 8s/step - loss: 0
- val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 104/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 105/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 106/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0351 - accuracy: 0.9903 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 107/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0573 - accuracy: 0.9806 - val_loss: 0.0078 - val_accuracy: 0.9944
# Epoch 108/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0249 - accuracy: 0.9931 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 109/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0432 - accuracy: 0.9875 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 110/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0473 - accuracy: 0.9903 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 111/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0199 - accuracy: 0.9958 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 112/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0255 - accuracy: 0.9903 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 113/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0348 - accuracy: 0.9833 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 114/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0490 - accuracy: 0.9903 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 115/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0533 - accuracy: 0.9847 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 116/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0443 - accuracy: 0.9903 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 117/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0259 - accuracy: 0.9903 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 118/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0614 - accuracy: 0.9875 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 119/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0347 - accuracy: 0.9889 - val_loss: 0.0052 - val_accuracy: 0.9944
# Epoch 120/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0347 - accuracy: 0.9903 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 121/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0332 - accuracy: 0.9944 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 122/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0426 - accuracy: 0.9903 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 123/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0473 - accuracy: 0.9833 - val_loss: 0.0054 - val_accuracy: 0.9944
# Epoch 124/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0316 - accuracy: 0.9917 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 125/150
# 9/9 [==============================] - 77s 9s/step - loss: 0.0323 - accuracy: 0.9889 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 126/150
# 9/9 [==============================] - 77s 9s/step - loss: 0.0734 - accuracy: 0.9722 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 127/150
# 9/9 [==============================] - 77s 9s/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 128/150
# 9/9 [==============================] - 78s 9s/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 129/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0310 - accuracy: 0.9944 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 130/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0254 - accuracy: 0.9931 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 131/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0390 - accuracy: 0.9931 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 132/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0280 - accuracy: 0.9917 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 133/150
# 9/9 [==============================] - 74s 8s/step - loss: 0.0299 - accuracy: 0.9917 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 134/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0209 - accuracy: 0.9917 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 135/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0303 - accuracy: 0.9903 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 136/150
# 9/9 [==============================] - 74s 8s/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 137/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0324 - accuracy: 0.9917 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 138/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0446 - accuracy: 0.9875 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 139/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0312 - accuracy: 0.9903 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 140/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0426 - accuracy: 0.9917 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 141/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0317 - accuracy: 0.9917 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 142/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0233 - accuracy: 0.9958 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 143/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 144/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0181 - accuracy: 0.9972 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 145/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0315 - accuracy: 0.9903 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 146/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0312 - accuracy: 0.9875 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 147/150
# 9/9 [==============================] - 76s 9s/step - loss: 0.0267 - accuracy: 0.9903 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 148/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0354 - accuracy: 0.9903 - val_loss: 8.5763e-04 - val_accuracy: 1.0000
# Epoch 149/150
# 9/9 [==============================] - 76s 8s/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 8.0674e-04 - val_accuracy: 1.0000
# Epoch 150/150
# 9/9 [==============================] - 75s 8s/step - loss: 0.0143 - accuracy: 0.9958 - val_loss: 6.9032e-04 - val_accuracy: 1.0000

# %%
# Plot the model Accuracy graph (Ideally, it should be Logarithmic shape)
plt.plot(history.history['accuracy'],'r',linewidth=3.0, label='Training Accuracy')
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0, label='Testing Accuracy')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# Plot the model Loss graph (Ideally it should be Exponentially decreasing shape)
plt.plot(history.history['loss'], 'g', linewidth=3.0, label='Training Loss')
plt.plot(history.history['val_loss'], 'y', linewidth=3.0, label='Testing Loss')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')
