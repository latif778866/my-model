# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore")
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, Dropout, MaxPool1D, Flatten
from sklearn.model_selection import train_test_split

# %%
# Setting the parameter to plot at 30x15 size
plt.rcParams['figure.figsize'] = 30, 15

# %%
root_folder_train = r'C:\Users\acer\Desktop\xxx\train'
root_folder_test = r'C:\Users\acer\Desktop\xxx\test'
category = ['Normal', 'Abnormal']
destination = r'C:\Users\acer\Desktop\New folder'

# %%
# Function to load the dataset and do the required formatting to be able to feed the data into the Keras Model
def load_data(root_folder):
    # These are delcarations of variables that have been used inside the for loop
    final_list = list()
    labels = list()
    # It is iterating through both the categories Normal and Abnormal
    for cat in category:
        # It is taking and processing each file in the folder
        #for filename in os.listdir(root_folder+cat):
        for filename in os.listdir(os.path.join(root_folder, cat)):
            
            # Read each file for each category and drop the unnecessary columns
            path = os.path.join(root_folder, cat, filename)
            #path = root_folder + cat + '\\' + filename
            df = pd.read_csv(path) # Read the CSV using inbuilt Pandas Function
            df.drop(index=0, axis=0, inplace=True) # Drop the first row, which contains the units of measurement (useless for our use case)
            df=df.iloc[:7680]
            df.columns = ["time", "ECG0", "ECG1"] # Rename the columns for convinience and easy access of the columns
            df.drop(['time'], axis=1, inplace=True) # Drop the time column, as we are not using it as a time series. We are using the indexes instead
            df.ECG0 = pd.to_numeric(df.ECG0) # The data by default is in the form of an object, Convert each row into numeric or floating point
            df.ECG1 = pd.to_numeric(df.ECG1)
            
            print(filename, len(df))
            
            # Split each file into 6 parts and then make each of them a new row by transposing
            df_split = np.array_split(df, 30) # Split the dataset into 30 different sets. This is not mandatory, but is suggested since the dataset size is less
            for splitted_array in df_split:
                final_list.append(np.array(splitted_array)) # After splitting, we are appending all the splitted arrays into 1 single large array of 3 dimentions
                # The following if-else block is used to create labels. We have taken '1' for AF ECG and '0' for Normal ECG
                # This is not the ideal way to create labels, but this is the most simplest way for this situation
                if cat == 'Normal':
                    labels.append(0)
                if cat == 'Abnormal':
                    labels.append(1)

    # Before returning, convert the lists to arrays and increase the dmentions for being able to feed into the Neural Network
    return np.array(final_list), np.expand_dims(np.array(labels), axis=1)

# %%
# Load the training and testing dataset separately by calling the function for each of their root folder locations
X_train, y_train = load_data(root_folder_train)
X_test, y_test = load_data(root_folder_test)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (15).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (10).csv 7680
# samples (11).csv 7680
# samples (12).csv 7680
# samples (13).csv 7680
# samples (14).csv 7680
# samples (3).csv 7680
# samples (4).csv 7680
# samples (5).csv 7680
# samples (6).csv 7680
# samples (7).csv 7680
# samples (8).csv 7680
# samples (9).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples (3).csv 7680
# samples (1).csv 7680
# samples (2).csv 7680
# samples.csv 7680
# (720, 256, 2) (720, 1)
# (180, 256, 2) (180, 1)

# %%
# Build the model

# The model architecture type is sequential hence that is used
model = Sequential()

# We are using 4 convolution layers for feature extraction
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu', input_shape=(256, 2)))
model.add(Conv1D(filters=512, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2)) # This is the dropout layer. It's main function is to inactivate 20% of neurons in order to prevent overfitting
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Conv1D(filters=256, kernel_size=32, padding='same', kernel_initializer='normal', activation='relu'))
model.add(MaxPool1D(pool_size=128)) # We use MaxPooling with a filter size of 128. This also contributes to generalization
model.add(Dropout(0.2))

# The prevous step gices an output of multi dimentional data, which cannot be fead directly into the feed forward neural network. Hence, the model is flattened
model.add(Flatten())
# One hidden layer of 128 neurons have been used in order to have better classification results
model.add(Dense(units=128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.5))
# The final neuron HAS to be 1 in number and cannot be more than that. This is because this is a binary classification problem and only 1 neuron is enough to denote the class '1' or '0'
model.add(Dense(units=1, activation='sigmoid'))

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 256, 512)          33280
#
#  conv1d_5 (Conv1D)           (None, 256, 512)          8389120
#
#  dropout_4 (Dropout)         (None, 256, 512)          0
#
#  conv1d_6 (Conv1D)           (None, 256, 256)          4194560
#
#  dropout_5 (Dropout)         (None, 256, 256)          0
#
#  conv1d_7 (Conv1D)           (None, 256, 256)          2097408
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 256)            0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 2, 256)            0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14780161 (56.38 MB)
# Trainable params: 14780161 (56.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the mode
# To my experience, the Stocastic Gradient Descent Optimizer works the best. Adam optimizer also works but not as good as SGD
optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(X_train, y_train,  batch_size=64, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 12/12 [==============================] - 73s 6s/step - loss: 6.9330 - accuracy: 0.5694 - val_loss: 0.2367 - val_accuracy: 0.9389
# Epoch 2/50
# 12/12 [==============================] - 76s 6s/step - loss: 1.4184 - accuracy: 0.7347 - val_loss: 0.2727 - val_accuracy: 0.9667
# Epoch 3/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.7888 - accuracy: 0.7694 - val_loss: 0.1944 - val_accuracy: 0.9611
# Epoch 4/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.5763 - accuracy: 0.8028 - val_loss: 0.2181 - val_accuracy: 0.9556
# Epoch 5/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.6171 - accuracy: 0.7903 - val_loss: 0.2525 - val_accuracy: 0.9722
# Epoch 6/50
# 12/12 [==============================] - 77s 6s/step - loss: 0.5234 - accuracy: 0.8417 - val_loss: 0.2289 - val_accuracy: 0.9667
# Epoch 7/50
# 12/12 [==============================] - 77s 6s/step - loss: 0.4094 - accuracy: 0.8625 - val_loss: 0.2489 - val_accuracy: 0.9667
# Epoch 8/50
# 12/12 [==============================] - 77s 6s/step - loss: 0.4606 - accuracy: 0.8500 - val_loss: 0.2150 - val_accuracy: 0.9667
# Epoch 9/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.3790 - accuracy: 0.8681 - val_loss: 0.1878 - val_accuracy: 0.9833
# Epoch 10/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.3661 - accuracy: 0.8611 - val_loss: 0.1938 - val_accuracy: 0.9778
# Epoch 11/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.3535 - accuracy: 0.8806 - val_loss: 0.1773 - val_accuracy: 0.9889
# Epoch 12/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.3499 - accuracy: 0.8861 - val_loss: 0.1737 - val_accuracy: 0.9889
# Epoch 13/50
# 12/12 [==============================] - 75s 6s/step - loss: 0.3390 - accuracy: 0.9028 - val_loss: 0.1524 - val_accuracy: 0.9778
# Epoch 14/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2354 - accuracy: 0.9069 - val_loss: 0.1362 - val_accuracy: 0.9944
# Epoch 15/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2614 - accuracy: 0.9083 - val_loss: 0.1291 - val_accuracy: 0.9944
# Epoch 16/50
# 12/12 [==============================] - 75s 6s/step - loss: 0.2741 - accuracy: 0.9208 - val_loss: 0.1219 - val_accuracy: 0.9889
# Epoch 17/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2738 - accuracy: 0.9153 - val_loss: 0.1239 - val_accuracy: 0.9889
# Epoch 18/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2641 - accuracy: 0.9250 - val_loss: 0.1077 - val_accuracy: 0.9944
# Epoch 19/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2405 - accuracy: 0.9167 - val_loss: 0.1129 - val_accuracy: 0.9944
# Epoch 20/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2582 - accuracy: 0.9181 - val_loss: 0.1043 - val_accuracy: 0.9944
# Epoch 21/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2133 - accuracy: 0.9306 - val_loss: 0.1063 - val_accuracy: 0.9944
# Epoch 22/50
# 12/12 [==============================] - 75s 6s/step - loss: 0.2177 - accuracy: 0.9292 - val_loss: 0.0982 - val_accuracy: 0.9944
# Epoch 23/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2071 - accuracy: 0.9292 - val_loss: 0.0966 - val_accuracy: 0.9944
# Epoch 24/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2098 - accuracy: 0.9319 - val_loss: 0.0888 - val_accuracy: 0.9944
# Epoch 25/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.1945 - accuracy: 0.9264 - val_loss: 0.0932 - val_accuracy: 0.9944
# Epoch 26/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.2109 - accuracy: 0.9417 - val_loss: 0.0857 - val_accuracy: 0.9944
# Epoch 27/50
# 12/12 [==============================] - 76s 6s/step - loss: 0.1529 - accuracy: 0.9472 - val_loss: 0.0872 - val_accuracy: 0.9944
# Epoch 28/50
# 12/12 [==============================] - 77s 6s/step - loss: 0.1544 - accuracy: 0.9458 - val_loss: 0.0874 - val_accuracy: 0.9944
# Epoch 29/50
# 12/12 [==============================] - 92s 8s/step - loss: 0.1466 - accuracy: 0.9500 - val_loss: 0.0800 - val_accuracy: 0.9944
# Epoch 30/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1952 - accuracy: 0.9528 - val_loss: 0.0765 - val_accuracy: 0.9944
# Epoch 31/50
# 12/12 [==============================] - 138s 12s/step - loss: 0.1145 - accuracy: 0.9542 - val_loss: 0.0758 - val_accuracy: 0.9944
# Epoch 32/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.1835 - accuracy: 0.9597 - val_loss: 0.0735 - val_accuracy: 0.9944
# Epoch 33/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1340 - accuracy: 0.9611 - val_loss: 0.0760 - val_accuracy: 0.9944
# Epoch 34/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.1336 - accuracy: 0.9514 - val_loss: 0.0714 - val_accuracy: 0.9944
# Epoch 35/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1130 - accuracy: 0.9653 - val_loss: 0.0682 - val_accuracy: 0.9944
# Epoch 36/50
# 12/12 [==============================] - 143s 12s/step - loss: 0.1354 - accuracy: 0.9486 - val_loss: 0.0699 - val_accuracy: 0.9944
# Epoch 37/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1507 - accuracy: 0.9528 - val_loss: 0.0767 - val_accuracy: 0.9944
# Epoch 38/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1030 - accuracy: 0.9625 - val_loss: 0.0645 - val_accuracy: 0.9944
# Epoch 39/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.1367 - accuracy: 0.9528 - val_loss: 0.0585 - val_accuracy: 0.9944
# Epoch 40/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.0836 - accuracy: 0.9708 - val_loss: 0.0653 - val_accuracy: 0.9944
# Epoch 41/50
# 12/12 [==============================] - 143s 12s/step - loss: 0.1082 - accuracy: 0.9625 - val_loss: 0.0636 - val_accuracy: 0.9944
# Epoch 42/50
# 12/12 [==============================] - 143s 12s/step - loss: 0.1186 - accuracy: 0.9611 - val_loss: 0.0591 - val_accuracy: 0.9944
# Epoch 43/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.1259 - accuracy: 0.9653 - val_loss: 0.0551 - val_accuracy: 0.9944
# Epoch 44/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.1126 - accuracy: 0.9625 - val_loss: 0.0584 - val_accuracy: 0.9944
# Epoch 45/50
# 12/12 [==============================] - 140s 12s/step - loss: 0.0655 - accuracy: 0.9819 - val_loss: 0.0584 - val_accuracy: 0.9944
# Epoch 46/50
# 12/12 [==============================] - 140s 12s/step - loss: 0.0977 - accuracy: 0.9722 - val_loss: 0.0546 - val_accuracy: 0.9944
# Epoch 47/50
# 12/12 [==============================] - 139s 12s/step - loss: 0.1083 - accuracy: 0.9681 - val_loss: 0.0482 - val_accuracy: 0.9944
# Epoch 48/50
# 12/12 [==============================] - 142s 12s/step - loss: 0.0991 - accuracy: 0.9681 - val_loss: 0.0499 - val_accuracy: 0.9944
# Epoch 49/50
# 12/12 [==============================] - 141s 12s/step - loss: 0.0906 - accuracy: 0.9764 - val_loss: 0.0492 - val_accuracy: 0.9944
# Epoch 50/50
# 12/12 [==============================] - 143s 12s/step - loss: 0.1129 - accuracy: 0.9694 - val_loss: 0.0499 - val_accuracy: 0.9944

# %%
# Plot the model Accuracy graph (Ideally, it should be Logarithmic shape)
plt.plot(history.history['accuracy'],'r',linewidth=3.0, label='Training Accuracy')
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0, label='Testing Accuracy')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# Plot the model Loss graph (Ideally it should be Exponentially decreasing shape)
plt.plot(history.history['loss'], 'g', linewidth=3.0, label='Training Loss')
plt.plot(history.history['val_loss'], 'y', linewidth=3.0, label='Testing Loss')
plt.legend(fontsize=18)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss Curves', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')
